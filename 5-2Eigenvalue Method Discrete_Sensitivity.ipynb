# %%
x1,x2 = var('x1 x2')
k = var('k')

# %%
# M = Matrix([[1-10*k,-5],[1,0]])
Eigens = M.eigenvalues()
show(Eigens)
# Out:
# [-5*k - 1/2*sqrt(100*k^2 - 20*k - 19) + 1/2,
#  -5*k + 1/2*sqrt(100*k^2 - 20*k - 19) + 1/2]

# %%
plot(Eigens,(k,0,1),legend_label=['lambda_2','lambda_1'])
# Out:
# verbose 0 (3763: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 109 points.
# verbose 0 (3763: plot.py, generate_plot_points) Last error message: 'Unable to compute f(0.543700329479)'
# verbose 0 (3763: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 110 points.
# verbose 0 (3763: plot.py, generate_plot_points) Last error message: 'Unable to compute f(0.546421374818)'
# Graphics object consisting of 2 graphics primitives
