# %%
x1,x2 =var('x1 x2')
lamda =var('lamda')
#t = var('t')

# %%
#x=function('x')(t)

# %%
plot_vector_field([-1*x1,-1*x2],(x1,-2,2),(x2,-2,2))#e.g. lambda = -2
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#E1= diff(x,t)==-x*lamda
#show(E1)
#S1=desolve(E1,x)
#show(S1)
# Out:
# diff(x(t), t) == -lamda*x(t)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-62b3de032f81> in <module>()
#       1 E1= diff(x,t)==-x*lamda
#       2 show(E1)
# ----> 3 S1=desolve(E1,x)
#       4 show(S1)
#
# /opt/sagemath-8.3/local/lib/python2.7/site-packages/sage/calculus/desolvers.pyc in desolve(de, dvar, ics, ivar, show_method, contrib_ode)
#     451         ivars = [t for t in ivars if t is not dvar]
#     452         if len(ivars) != 1:
# --> 453             raise ValueError("Unable to determine independent variable, please specify.")
#     454         ivar = ivars[0]
#     455     de00 = de._maxima_()
#
# ValueError: Unable to determine independent variable, please specify.

# %%
#lamda
# Out:
# lamda
